# %% [markdown]
# <a href="https://colab.research.google.com/github/rugellioliveira/Visualizacao_de_Dados_com_Matplotlib/blob/main/Visualiza%C3%A7%C3%A3o_de_dados_com_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plotando gráficos simples:

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(7)
y = np.random.randint(low = 1, high = 1500, size = 10) #valores inteiros pseudo-aleatórios entre 1 e 1500, com 10 amostras
plt.plot(y) #plota os valores

# %%
plt.plot(y, color = '#749187', marker = 'o', ms = 5, mec = 'k', markerfacecolor = 'w', ls = '-.') #insere primeira linha
plt.plot(y*2, marker = '+', color = 'k', ms = 5) #insere segunda linha

#Rótulos
plt.xlabel('Eixo X', color = 'red', size = 12)
plt.ylabel('Eixo Y')
plt.title('Título', loc = 'left')

#linhas de grade
plt.grid(axis = 'y', color = 'gray', linestyle = '--', linewidth = 1, alpha = 0.8)
plt.show()

# %% [markdown]
# Plotando gráficos e ajustando parâmetros:

# %%
# Gerando numeros com o numpy
Dados_x = np.linspace(0, 10, 200) # retorna valores uniformemente espaçados dentro do determinado definido.
Dados_y = Dados_x * Dados_x

# Ajustando a figura
plt.figure(
          figsize=(10,5), # Ajustando o tamanho do gráfico
          facecolor='gray' # Ajustando cor de fundo
)

# Adicionando eixos
Ax = plt.axes()
Ax.set_facecolor('white') # Definindo cor de fundo no gráfico

#Criando o gráfico e passando parâmetros para ajustes
plt.plot(
         Dados_x, Dados_y, # Dados do gráficos
         color='magenta', # Cor da linha
         linewidth=2, # Espessura da linha
         markersize=5, # Tamanho do marcador
         marker='o', # Tipo do marcados
         linestyle='dashed', # Tipo da linha
         markeredgecolor='black', # Cor linha do marcador
)

# Definindo label do eixo x
plt.xlabel(
            'Eixo x', # nome do label
            fontweight='bold', # estilo
            fontsize='large', # Tamanho da fonte
            fontfamily='fantasy', # Tipo da fonte
            color='blue', # Cor da Fonte
)

# Definindo label do eixo y
# Mesmo parâmetros pode ser aplicado do 'xlabel'
plt.ylabel( 'Eixo y' )

# Definindo um titulo
plt.title(
          'Gráfico Simples', # Título do Gráfico
          fontweight='bold', # Estilo da fonte
          fontsize='xx-large', # Tamanho da fonte
          fontfamily='fantasy', # Tipo da fonte
          color='blue', # Cor da Fonte
)

# Definindo as legendas
plt.legend(
           'Números Aleatórios', # Nome da legenda
           loc='upper center', # Posição da legenda
           bbox_to_anchor=(1, 0., 0.0, 0.2), # Posição legenda na Figura
           fontsize='large', # Tamanho do texto
           shadow=True, # Sombra na legenda
           borderpad=1, # Bordar da legenda
);
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 225 (\N{LATIN SMALL LETTER A WITH ACUTE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 225 (\N{LATIN SMALL LETTER A WITH ACUTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Subplots:

# %%
np.random.seed(6)
x = np.arange(1, 11) # retorna valores uniformemente espaçados dentro do determinado definido.
y1 = np.random.randint(1, 400, 10)
y2 = np.random.randint(150, 500, 10)
y3 = np.random.randint(200, 600, 10)

plt.figure(figsize = (15, 5))
plt.suptitle('Figura', fontsize = 15)

# Grafico na 1º posição da Grade
plt.subplot(1, 3, 1)
plt.plot(x, y1, color = 'k')
plt.title('Subplot 1', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

# Grafico na 2º posição da Grade
plt.subplot(1, 3, 2)
plt.plot(x, y2, color = 'm')
plt.title('Subplot 2', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

# Grafico na 3º posição da Grade
plt.subplot(1, 3, 3)
plt.plot(x, y3, color = 'g')
plt.title('Subplot 3', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.tight_layout(pad = 4) # ajusta o espaçamento entre os subplots
plt.show()

# %%
fig ,ax = plt.subplots(1, 3, figsize = (15, 5))

fig.suptitle('Figura')
ax[0].plot(x, y1, color = 'black')
ax[1].plot(x, y2, color = 'red')
ax[2].plot(x, y3, color = 'green')

for i in range(3):
  ax[i].set(title = f'Subplot {i + 1}', xlabel = 'Eixo X', ylabel = 'Eixo Y')

# %%
# Definindo a dimensão da Grade
Linhas = 2
Colunas = 2

# Grafico na 1º posição da Grade
plt.subplot( Linhas, Colunas, 1 )
plt.plot( Dados_x, 'r--' )
plt.title('Grafico 1')

# Grafico 2º posição da Grade
plt.subplot( Linhas, Colunas, 2 )
plt.plot( Dados_y, 'g-' )
plt.title('Grafico 2')

# Grafico 3º posição da Grade
plt.subplot( Linhas, Colunas, 3 )
plt.plot( Dados_y , 'y-' )
plt.title('Grafico 3')

# Grafico 4º posição da Grade - Incluindo 2 eixos
plt.subplot( Linhas, Colunas, 4 )
plt.plot( Dados_x , 'b--' )
plt.plot( Dados_y , 'p--' )
plt.title('Grafico 4')

plt.tight_layout(pad = 1)
plt.show()

# %% [markdown]
# Gráfico com mini gráfico acoplado:

# %%
# Criando uma nova firua
Figura = plt.figure()

# Definindo o tamanho do grafico
Eixo_1 = Figura.add_axes([0.1, 0.1, 0.8, 0.8]) #[left, bottom, width, height]

# Definindo o tamanho do grafico acoplado
Eixo_2 = Figura.add_axes([0.2, 0.5, 0.3, 0.3])

# Plotando os graficos
Eixo_1.plot( Dados_x, Dados_y, 'r--' )
Eixo_2.plot( Dados_y, Dados_x, 'y' );

# %% [markdown]
# Histograma e boxplot:

# %%
data = np.random.normal(10, 0.5, 5000)
plt.hist(data)
plt.show()

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6e021d8a00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6e021d9780>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6e021d8460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6e021d9cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6e021db040>],
#  'means': []}

# %% [markdown]
# Gráfico de dispesão ou Scatter plot:
#
# (Representações gráficas do relacionamento entre duas variáveis numéricas).

# %%
x = np.random.normal(10, 0.5, 100)
y = np.random.uniform(0, 20, 100)
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y, marker = 'o', color = 'red', label = 'data1', alpha = 0.5)
ax.scatter(x*0.5, y*0.5, marker = 'v', color = 'black', label = 'data2', alpha = 0.7)
ax.legend()

# %% [markdown]
# Gráfico de Barras:

# %%
# Criando a figura
Figura = plt.figure()

Dados_z = np.linspace(1, 200, 10)

# Definindo o Tamanho
Grafico = Figura.add_axes([0, 0, 0.7, 0.7])

# Definindo os rotulos
Rotulos = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# Gerando o gráfico
Grafico.bar(Rotulos,Dados_z);

# %% [markdown]
# Gráfico de Barras com mais eixos:

# %%
# Criando a figura
Figura = plt.figure()

# Definindo o Tamanho
Grafico = Figura.add_axes([0, 0, 0.7, 0.7])

# Definindo os rotulos
Rotulos = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# Gerando o gráfico
Grafico.bar(Rotulos, Dados_z, color='r')
Grafico.bar(Rotulos, Dados_z * 0.5, color='b');

# %% [markdown]
# ///////////////////////// **Exemplo com Dados Econômicos:** ////////////////////

# %%
import plotly.express as px

px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df = px.data.gapminder().query('country == "Brazil"').set_index('year')
df.head()
# Out:
#      country continent  lifeExp        pop    gdpPercap iso_alpha  iso_num
# year
# 1952  Brazil  Americas   50.917   56602560  2108.944355       BRA       76
# 1957  Brazil  Americas   53.285   65551171  2487.365989       BRA       76
# 1962  Brazil  Americas   55.665   76039390  3336.585802       BRA       76
# 1967  Brazil  Americas   57.632   88049823  3429.864357       BRA       76
# 1972  Brazil  Americas   59.504  100840058  4985.711467       BRA       76

# %%
plt.plot(df.index, df['gdpPercap'])
plt.title('PIB per capita do Brasil')
plt.ylabel('PIB per capita')
plt.xlabel('Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
title = 'Relação entre expectativa de vida e renda per capita no Brasil'
plt.figure(figsize = (12, 4))
plt.scatter(df['lifeExp'], df['gdpPercap'], cmap = 'viridis')
plt.xlabel('Expectativa de vida')
plt.ylabel('Renda per capita')
plt.title(title, loc = 'left')
plt.show()
# Out:
# <ipython-input-56-dca061ca67d9>:3: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
plt.bar(x = df.index, height = df['pop'], color = 'red')
plt.title('População brasileira')
# Out:
# Text(0.5, 1.0, 'População brasileira')

# %%
def filtrar_continente(continente):
  df = px.data.gapminder()
  df = df[df['continent'] == continente]
  return df

# %%
def filtrar_pais (pais, variavel):
  'Filtrar algum país das amostras para as variavéis "pop", "gdpPercap" e "lifeExp"'
  df = px.data.gapminder()
  df = df[df['country'] == pais][variavel]
  return df

# %%
americas = filtrar_continente('Americas')
paises = americas['country'].unique()
plt.figure(figsize = (12, 8))

for pais in paises:
  plt.scatter( filtrar_pais (pais = pais, variavel = 'lifeExp'),
              filtrar_pais(pais = pais, variavel = 'gdpPercap'))
  plt.legend(labels = paises, loc = 'best')
  plt.title('Relação entre renda per capita e expectativa de vida', loc = 'left')
  plt.xlabel('Expectativa de vida')
  plt.ylabel('Renda per capita')
